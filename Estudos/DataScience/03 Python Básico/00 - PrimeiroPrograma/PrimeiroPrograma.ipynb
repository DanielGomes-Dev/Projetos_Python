# %%
# Variaveis
print('Olá Mundo')
quantidade_de_vendas = 1500;
print('quantidade de vendas: ', quantidade_de_vendas)

# %%
## Tipos de Variaveis
faturamento = 1500.20;
active = True;

print('faturamento: ', quantidade_de_vendas)

print(type(quantidade_de_vendas))
print(type(faturamento))
print(type(active))

# %%
## Condições

faturamento = 400

if(faturamento > 1000):
    print('Faturamento maior que 1000: ' ,faturamento)
else:
    print('Faturamento menor que 1000: ', faturamento)

if faturamento > 1000:
    print ('faturamento de {} é maior que {}'.format(faturamento, 1000))
    
elif faturamento == 400:
    print ('faturamento é  {}'.format(faturamento))

else:
    print ('faturamento de {} é menor que {}'.format(faturamento, 1000))

# %%
email = '123@gmail.com'
password = input('insira a senha')
if '@' in email:
    print('email valido')
    
if '4' not in email:
    print('4 not in email {}'.format(email))
else:
    pass

if not password and not email:
    print('insira a senha')
    
if not password or email:
    print('insira a senha')

# %%
email = '12345@gmail.com'
nome = 'daniel'

print(len(email))
print(len(nome))
print(email[5])
print(nome[3])
print(email[-1])

print(email.split('@'))
print(email.split('@')[1])
print(email[:5])
print(email[:-5])

print(email[5:])
print(email[:-5])

# %%
## format
print(nome.upper().casefold())
print(nome.upper().casefold())
print(nome.upper().lower())
print(nome.capitalize())
print(nome.count('a'))

print(nome.endswith('l'))
print(nome.endswith('el'))
print(nome.endswith('e'))

print(nome.startswith('d'))
print(nome.startswith('da'))
print(nome.startswith('e'))

print(nome.find('n'))

print(nome.isalnum())
print(nome.isalpha())
print(nome.isnumeric())

print(nome.replace('a','@'))
print(nome.split('n'))
print((nome+'\n 123').splitlines()) ## Divide no enter \n

print((nome+ '222    ').strip())

print((nome+' test').title())
print((nome+' test').upper())

# %%
# Listas

products = ['tv', 'radio', 'celular', 'mouse', 'teclado', nome]
vendas = [1000, 233, 1234, 321, 222, faturamento]

print(products)
print(vendas)

print(products[2])

print('vendas do produto {} foi de {}'.format(products[0], vendas[0]))
print('vendas do produto {} foi de {}'.format(products[2], vendas[2]))

vendas[2] = 999

print('vendas do produto {} foi de {}'.format(products[2], vendas[2]))

# %%
# Repetição

for i in range(3):
    print(i)
    
for i in range(len(vendas)):
    print('Produto {} foi vendido {} vezes'.format(products[i],vendas[i]))
    
for product in products:
    print(product)

# %%
for product in products:
    if(product == 'tv'):
        print('tv')
        
total_vendas = len(vendas)
total_vendas_maior_que_meta = 0
for venda in vendas:
    if(venda > 399):
        total_vendas_maior_que_meta += 1
        print(venda)
        
percent = total_vendas_maior_que_meta/total_vendas*100
percent2 = 100/total_vendas*total_vendas_maior_que_meta
percent3 = total_vendas_maior_que_meta/total_vendas




print('A porcentagem de pessoas que alcançou a meta de vendas foi de {:.1f}% ou {}% ou {:.2%}'.format(percent+0.22, percent2, percent3))

# %%
count_while = 0

while count_while < 10:
    count_while+=1;
    print('contador: {}'.format(count_while))

# %%
#Tuplas
# Tuplas são imutaveis
# mais rapidas
# mais seguras

tuplas_in_python = (1,2,3, 'abc')

print(tuplas_in_python)
print(tuplas_in_python[2])


## Unpacking tuplas

valor1, valor2, valor3, valor4 = tuplas_in_python;

print(valor1, valor2, valor3, valor4, 'Unpacking seria algo parecido com a desestruturação de arrays do js')


## Enumerate que vinhamos usando até agora na verdade cria uma tupla para a gente;

enum_tupla = [1,3,5,6,8,10]
enum_tupla2 = [1+1,3+3,5+6,6+1,8+3,10+12]

for item in enumerate(enum_tupla2):
    print(item)
    
for i, item in enumerate(enum_tupla2):
    print('index',i, 'value',item)
# Out:
# (1, 2, 3, 'abc')
# 3
# 1 2 3 abc Unpacking seria algo parecido com a desestruturação de arrays do js
# (0, 2)
# (1, 6)
# (2, 11)
# (3, 7)
# (4, 11)
# (5, 22)
# index 0 value 2
# index 1 value 6
# index 2 value 11
# index 3 value 7
# index 4 value 11
# index 5 value 22

# %%
#F047 Dicionario

dicionario = {
    'chave': 'valor', # type: ignore
    'chave2': 'valor2' # type: ignore
}

print(dicionario, dicionario['chave'], dicionario.get('chave2'))

# Dicionario são objetos

#F048 Dicionario

print(dicionario.get('123')) # não da erro e retorna none


if(not dicionario.get('123')):
    print('nao existe essa chave1')    
    
if('123' not in dicionario):
    print('nao existe essa chave2')   
    
if(dicionario.get('123') == None):
    print('nao existe essa chave3')   

# print(dicionario['123']) # da erro e quebra a aplicação
# Out:
# {'chave': 'valor', 'chave2': 'valor2'} valor valor2
# None
# nao existe essa chave1
# nao existe essa chave2
# nao existe essa chave3

# %%
#F049

# Range

range_array = [50,100,20,5,80]

for i in range(5):
    print('print {} range'.format(i))

print(range(1,10))

for i in range(5,10):
    print(i, 'i')
    
for i in range(1,10, 2):
    print(i, 'h')
# Out:
# print 0 range
# print 1 range
# print 2 range
# print 3 range
# print 4 range
# range(1, 10)
# 5 i
# 6 i
# 7 i
# 8 i
# 9 i
# 1 h
# 3 h
# 5 h
# 7 h
# 9 h

# %%
# F050 funções
# F051 return
# F052 argumentos


# Functions

def nome_func():
    print('função1')
    return 19

def nome_func2(value):
    print('função2')
    return value

def nome_func3(value1, value2):
    print('função3')
    return {value1, value2}

def nome_func4(value1):
    print('função4')
    return {'test1': value1['valor1'], 'test2': value1.get('valor2')}

func_return = nome_func()
func_return2 = nome_func2('value')
func_return3 = nome_func3('value 1', 'value 2')
func_return4 = nome_func4({
    'valor1': 'value test 01',
    'valor2': 'value test 02'
    
})


print(func_return)
print(func_return2)
print(func_return3)
print(func_return4)
# Out:
# função1
# função2
# função3
# função4
# 19
# value
# {'value 1', 'value 2'}
# {'test1': 'value test 01', 'test2': 'value test 02'}

# %%
# Exercicio Função
# F053
    

# F054 Módulos -> importação

import math 
from math import sqrt as raiz

raiz(4)

import webbrowser
import webbrowser as wb

# webbrowser.open('https://www.google.com')
# wb.open('https://www.google.com')

# %%
# F055 Incrementais

faturamento_increment = 500
faturamento_increment = faturamento_increment + 900
print(faturamento_increment);

listas_increment = ['ipad', 'iphone']
vendas_increment = [100, 200]
print(listas_increment)
listas_increment = listas_increment + ['mac']
listas_increment.append('mac pro')
listas_increment += ['mac pro 14']

print(listas_increment)

# F056 QUIZ
# Out:
# 1400
# ['ipad', 'iphone']
# ['ipad', 'iphone', 'mac', 'mac pro', 'mac pro 14']
