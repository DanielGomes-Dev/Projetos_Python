# %% [markdown]
# # Pandas e Numpy As bibliotecas básicas para Ciência de Dados
#
# ## F057 Apresentando as bibliotecas NumPy e Pandas
#
# - São bibliotecas do python voltadas para ciencia de dados
#
# - NumPy é a principal biblioteca de computação do python, otimizada para calculos pesados e serve de base para o pandas
#
#   - no numpy vamos trabalhar com arrays, que são estruturas de dados multi dimensionais (1D, 2D, 3D)
#   - os Arrays lembram muito as listas, porém algumas diferenças e varias vantagens na questão de processamento
#
# - Pandas vai ser a biblioteca que vamos utilizar em toda a parte inicial do nosso processos de ciencia de dados! Além de possuir alta performance e facil uso para trabalharmos com estruturas de dados, possui um visual muito amigavel ao usuario não tecnico
#   - os Data FRames do Pandas lembram muito o excel, popurlamente conhecido nas empresas
#   - É usado desde a importação da base até a criação do modelo, incluindo a análise e visualização dos dados, tratamentos, agregações, etc..
#
# <https://pandas.pydata.org/docs/index.html>
#
# ```python
# df = pd.DataFrame(
#     {
#         "Name": [
#             "Braund, Mr. Owen Harris",
#             "Allen, Mr. William Henry",
#             "Bonnell, Miss. Elizabeth",
#         ],
#         "Age": [22, 35, 58],
#         "Sex": ["male", "male", "female"],
#     }
# )
# ```

# %%
import pandas as pd
import os
print(os.listdir())
# Pandas vs Excel
# Tabela -> DataFrame
# Coluna -> Series

# %%
# Lendo uma base no Pandas

try:
    base = pd.read_csv('spotify_top_songs_2024.csv')
    print(base.head())  # Exibe as primeiras linhas para confirmar a leitura
except Exception as e:
    print(f"Erro ao ler o arquivo Excel: {e}")
   
print()
print(base)

# %%
# Verificando o tipo desse dados

print(base.dtypes)
type(base)

# %%
# Visualizando a Base

print(base.head())
print()
base
print()
base.head(4)
base.tail(4)

# %%
# Verificando o tipo de dado em cada uma das colunas

base.info()

# %%
# Filtrando apenas valores

print (base['Views'] > 50000)
base[base['Views'] > 50000]

# %%
base[base['Artist'] == 'Taylor Swift']

# %%
# Grafico de Disperção

base.plot.scatter(x='Rank', y='Views', alpha=0.5);

# %%
# Média de uma coluna

base['Views'].mean()
